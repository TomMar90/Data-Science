# %% [markdown]
# ___
# # Matplotlib
# Official website: http://matplotlib.org

# %% [markdown]
# ## Installation
#
# In terminal:
#
#  ``   conda install matplotlib ``
#
#
# or
#
#
#  ``   pip install matplotlib ``
#
# ## Importing
# In Jupyter import library after installation by command:
#
# ```python
# import matplotlib.pyplot as plt
# ```
#
# and to see plots in the notebooks
#
# ```python
# %matplotlib inline
# ```
# That above line is only for jupyter notebooks, if you are using another editor, you'll use:
# ```python
# plt.show()
# ```
# at the end of all your plotting commands to have the figure pop up in another window.
# <br>On the website we have a list of availables style of plots  https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
import math as mat
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-bright')

# %% [markdown]
# ### Example 1

# %%
import numpy as np
x = np.linspace(0, 10, 20)
y = np.power(x,2)

# %%
x

# %%
plt.plot(x, y, 'r') # 'r' is the color red #
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Title')
plt.show()

# %% [markdown]
# ## Example 2

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') # More on color options later
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %% [markdown]
# ___
# ## Example 3  Matplotlib Object Oriented Approach

# %%
x = np.linspace(-np.pi, np.pi, 300)
y = np.sin(x)
z= np.cos(x)

# %%
fig = plt.figure(figsize=(13,4)) #creature figure, empty canvas
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # add set of axes to figure: left, bottom, width, height (range 0 to 1)
axes.plot(x, y, color='blue', linewidth=3, linestyle ='--') # draw on that set of axes
axes.plot(x,z,color ='green', linewidth=3, linestyle='-.')
axes.set_xlabel('X') 
axes.set_xlim(-2*np.pi,2*np.pi)
axes.set_ylabel('Y')
axes.set_title('$\sin(x)$ vs $\cos(x)$')
axes.legend(['$\sin(x)$','$\cos(x)$'])
